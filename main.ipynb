# %% [markdown]
# # File to run all scripts.
# ## This file will run all scripts and generate all plots and artifacts that is used cross the scripts. Before running the file make sure to run:
#  ## pip install -r requirements.txt
# ### Not all plots and calculations are used in the report.

# %%
# main.ipynb
# %run phase1_data.ipynb
# %run phase2_linear.ipynb
# %run phase3_nonlinear.ipynb
# %run phase4_evaluation.ipynb
# Out:
# artifacts dir -> /Users/venello/Repositories/Python/PyCharm/PycharmProjects/computation_data_analysis/delivery_cda_case2/artifacts/case2_phase1
# shape: (312, 70)
# metadata      :   8 cols
# self-report   :  11 cols
# biosignal (X) :  51 cols
#   HR          : 12
#   TEMP        : 12
#   EDA_P       : 12
#   EDA_T       : 12
#   EDA peaks   : 3
# n subjects (Individual): 26
# n subjects (original_ID): 20   <- non-unique after cohort renaming; use Individual as canonical ID
# observations per subject: [12]
#
# phase balance:
# Phase
# phase3    104
# phase2    104
# phase1    104
# Name: count, dtype: int64
#
# rounds per phase:
# Phase    phase1  phase2  phase3
# Round
# round_1      26      26      26
# round_2      26      26      26
# round_3      26      26      26
# round_4      26      26      26
#
# cohort sizes (subjects per cohort):
# Cohort
# D1_1    8
# D1_2    6
# D1_3    4
# D1_4    4
# D1_5    2
# D1_6    2
# Name: Individual, dtype: int64
#
# duplicate rows: 0
# ...
